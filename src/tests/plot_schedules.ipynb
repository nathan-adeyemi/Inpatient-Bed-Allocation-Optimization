# %%
import sys
sys.path.append('../src')
import matplotlib.pyplot as plt
import seaborn as sns

from utils.utils import plot_probs, plot_temps

# %%
temp_init = 10
alpha = 1.27
sched_name = 'exponential'

plot_probs(t_0 = temp_init, t_damp = alpha ,sched=sched_name,plot=True)
plot_temps(t_0 = temp_init, t_damp = alpha,sched=sched_name,plot=True)

probs = plot_probs(t_0 = temp_init, t_damp = alpha,sched=sched_name,plot=False)
temps = plot_temps(t_0 = temp_init, t_damp = alpha ,sched=sched_name,plot=False)
